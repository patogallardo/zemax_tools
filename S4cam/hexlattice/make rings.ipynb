# %%
from hexlattice import *
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = getConcentricRings(6, 1)

# %%
plt.figure(figsize=[8,8])
plt.scatter(df.x, df.y, 
            color=['C%i' %df.ring.values[i] for i in range(len(df))])
plt.axis('equal');

# %%
df = getConcentricRings(3, 170)
plt.figure(figsize=[8,8])
plt.scatter(df.x, df.y, 
            color=['C%i' %df.ring.values[i] for i in range(len(df))])
plt.axis('equal');

# %% [markdown]
# # 85 camera layout

# %%
df = gen85CamPosition(scale=220/np.sqrt(3))

# %%
plt.figure(figsize=[8,8])
plt.scatter(df.x, df.y, 
            color=['C%i' %df.ring.values[i] for i in range(len(df))])
plt.axis('equal');

# %%
df.shape
# Out:
# (85, 6)

# %%
df.head(10)
# Out:
#        x           y  hex_x  hex_y  ring  angle
# 0    0.0    0.000000      0      0     0    0.0
# 1  220.0    0.000000      1      0     1    0.0
# 2  110.0  190.525589      0      1     1   60.0
# 3 -110.0  190.525589     -1      1     1  120.0
# 4 -220.0    0.000000     -1      0     1  180.0
# 5 -110.0 -190.525589      0     -1     1  240.0
# 6  110.0 -190.525589      1     -1     1  300.0
# 7  440.0    0.000000      2      0     2    0.0
# 8  330.0  190.525589      1      1     2   30.0
# 9  220.0  381.051178      0      2     2   60.0

# %%
df
# Out:
#         x           y  hex_x  hex_y  ring       angle
# 0     0.0    0.000000      0      0     0    0.000000
# 1   220.0    0.000000      1      0     1    0.000000
# 2   110.0  190.525589      0      1     1   60.000000
# 3  -110.0  190.525589     -1      1     1  120.000000
# 4  -220.0    0.000000     -1      0     1  180.000000
# ..    ...         ...    ...    ...   ...         ...
# 80  330.0 -952.627944      4     -5     5  289.106605
# 81  660.0 -762.102355      5     -4     5  310.893395
# 82  770.0 -571.576766      5     -3     5  323.413224
# 83  880.0 -381.051178      5     -2     5  336.586776
# 84  990.0 -190.525589      5     -1     5  349.106605
#
# [85 rows x 6 columns]
